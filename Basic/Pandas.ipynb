# %%
import pandas as pd

# %%
A = [[1,2,3], [2,3,4], [4,5,6]]

# %%
B = pd.DataFrame(A, columns=['First','Second','Third'], index=['ex-1', 'ex-2', 'ex-3'])
B
# Out:
#       First  Second  Third
# ex-1      1       2      3
# ex-2      2       3      4
# ex-3      4       5      6

# %%
c = B.iloc[:,0:2]
c
# Out:
#       First  Second
# ex-1      1       2
# ex-2      2       3
# ex-3      4       5

# %%
B.loc['ex-2', ['First', 'Second']]
# Out:
# First     2
# Second    3
# Name: ex-2, dtype: int64

# %%
B.replace(6,33)
# Out:
#       First  Second  Third
# ex-1      1       2      3
# ex-2      2       3      4
# ex-3      4       5     33

# %%
B.replace({5:100,6:200})
# Out:
#       First  Second  Third
# ex-1      1       2      3
# ex-2      2       3      4
# ex-3      4     100    200

# %%
B.drop('ex-2', axis=0)
# Out:
#       First  Second  Third
# ex-1      1       2      3
# ex-3      4       5      6

# %%
B.drop('First', axis=1)
# Out:
#       Second  Third
# ex-1       2      3
# ex-2       3      4
# ex-3       5      6
